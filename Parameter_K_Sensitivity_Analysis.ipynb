# %% [markdown]
# ## 1. 可视化准确率对参数K的敏感性(ADJ)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 1, figsize=(5, 4))

x = [1, 2, 3, 4, 5,6]
# Weibo
y1 = [84.99, 88.74, 90.29, 89.83,  89.42, 88.61]
# Cora
y2 = [51.82, 67.82, 83.29, 92.59, 92.89, 89.45]
# Reddit
y3 = [56.67, 99.99, 99.98, 99.99,  99.98, 99.95]
#Disney
y4 = [90.37, 91.85, 90.74, 92.22, 89.63, 95.56]
#Books
y5 = [96.43, 99.80, 99.78, 99.03, 91.07, 96.43]
#Enron
y6 = [98.89, 99.64, 96.05, 93.38, 100.0, 98.82]

# 不同的点样式
styles = ['o', 's', '^', 'D', 'v', 'p']
# 绘制不同样式的点
for i, y in enumerate([y1, y2, y3, y4, y5, y6]):
    plt.plot(x, y, marker=styles[i])

plt.xlabel("K")
plt.ylabel(r"$ AUC\ \left(\%\right)$")
plt.title(r"$ SEGA-C\ \left(Adj\right)$")
         
axes.legend(['Weibo', 'Cora', 'Reddit', 'Disney','Books', 'Enron'], 
               ncol=2,                     # 每行 2 个图例项
               loc='lower right')

# %% [markdown]
# ## 1. 可视化运行试卷对参数K的敏感性

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 1, figsize=(5, 4))

x = [1, 2, 3, 4, 5,6]
# Weibo
y1 = [111.02, 385.28, 769.15, 1073.95,  1348.93, 1694.17]
# Cora
y2 = [196.27, 216.91, 277.36, 392.41, 412.51, 456.23]
# Reddit
y3 = [89.63, 148.40, 193.60, 246.67,  300.31, 355.94]
#Disney
y4 = [52.46, 52.65, 53.54, 54.16, 55.14, 55.33]
#Books
y5 = [55.16, 56.39, 57.44, 58.12, 59.90, 60.51]
#Enron
y6 = [77.09, 103.77, 128.85, 152.49, 177.37, 199.53]
# 不同的点样式
styles = ['o', 's', '^', 'D', 'v', 'p']
# 绘制不同样式的点
for i, y in enumerate([y1, y2, y3, y4, y5, y6]):
    plt.plot(x, y, marker=styles[i])
    
plt.xlabel("K")
plt.ylabel(r'$ Time\ \left(s\right)$')
plt.title(r"$ SEGA-C\ \left(Adj\right)$")
         
axes.legend(['Weibo', 'Cora', 'Reddit', 'Disney','Books', 'Enron'], 
               ncol=2,                     # 每行 2 个图例项
               loc='upper left')

# %%
#  1. 可视化准确率对参数K的敏感性(lab)
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 1, figsize=(5, 4))

x = [1, 2, 3, 4, 5,6]
# Weibo
y1 = [50.56, 75.29, 79.59, 81.83,  82.23, 82.50]
# Cora
y2 = [51.82, 77.51, 81.90, 82.15, 87.70, 86.72]
# Reddit
y3 = [56.67, 99.99, 99.98, 99.99,  99.98, 99.95]
#Disney
y4 = [50.00, 50.00, 50.00, 50.00, 50.00, 50.00]
#Books
y5 = [45.52, 82.38, 85.10, 90.43, 70.69, 82.24]
#Enron
y6 = [50.07, 59.71, 90.94, 94.56, 83.28, 96.43]

# 不同的点样式
styles = ['o', 's', '^', 'D', 'v', 'p']
# 绘制不同样式的点
for i, y in enumerate([y1, y2, y3, y4, y5, y6]):
    plt.plot(x, y, marker=styles[i])

plt.xlabel("K")
plt.ylabel(r"$ AUC\ \left(\%\right)$")
plt.title(r"$ SEGA-C\ \left(Lap\right)$")
         
axes.legend(['Weibo', 'Cora', 'Reddit', 'Disney','Books', 'Enron'], 
               ncol=2,                     # 每行 2 个图例项
               loc='lower right')

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 1, figsize=(5, 4))

x = [1, 2, 3, 4, 5,6]
# Weibo
y1 = [111.02, 385.28, 769.15, 1073.95,  1348.93, 1694.17]
# Cora
y2 = [237.52, 232.87, 275.28, 502.09, 673.38, 848.95]
# Reddit
y3 = [85.51, 141.35, 197.03, 252.80,  304.37, 364.38]
#Disney
y4 = [53.77, 54.84, 55.38, 55.81, 56.38, 56.91]
#Books
y5 = [57.24, 58.73, 59.62, 61.46, 62.02, 63.15]
#Enron
y6 = [80.01, 107.71, 131.71, 155.61, 180.40, 203.66]
# 不同的点样式
styles = ['o', 's', '^', 'D', 'v', 'p']
# 绘制不同样式的点
for i, y in enumerate([y1, y2, y3, y4, y5, y6]):
    plt.plot(x, y, marker=styles[i])
    
plt.xlabel("K")
plt.ylabel(r'$ Time\ \left(s\right)$')
plt.title(r"$ SEGA-C\ \left(Lap\right)$")
         
axes.legend(['Weibo', 'Cora', 'Reddit', 'Disney','Books', 'Enron'], 
               ncol=2,                     # 每行 2 个图例项
               loc='upper left')
